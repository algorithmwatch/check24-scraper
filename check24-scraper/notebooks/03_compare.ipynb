# %%
import lux
from sqlalchemy import create_engine
import pandas as pd
engine = create_engine("postgresql://postgres:postgres@localhost:5432/postgres")

# %%
df = pd.read_sql_query('select * from "results"',con=engine)

# %%
df['dob'] = pd.to_datetime(df['dob'], format='%Y-%m-%d')
df['dob'] = df['dob'].apply(lambda x: x.year)

# %%
df.set_data_type({'dob':'quantitative'})

# %%
df[df['provider'] == 'Europa']
# Out:
# /Users/user/Library/Caches/pypoetry/virtualenvs/check24-scraper-r50V5qXw-py3.9/lib/python3.9/site-packages/IPython/core/formatters.py:921: UserWarning:
# Unexpected error in rendering Lux widget and recommendations. Falling back to Pandas display.
# Please report the following issue on Github: https://github.com/lux-org/lux/issues
#
# /Users/user/Library/Caches/pypoetry/virtualenvs/check24-scraper-r50V5qXw-py3.9/lib/python3.9/site-packages/lux/core/frame.py:632: UserWarning:Traceback (most recent call last):
#   File "/Users/user/Library/Caches/pypoetry/virtualenvs/check24-scraper-r50V5qXw-py3.9/lib/python3.9/site-packages/lux/core/frame.py", line 594, in _ipython_display_
#     self.maintain_recs()
#   File "/Users/user/Library/Caches/pypoetry/virtualenvs/check24-scraper-r50V5qXw-py3.9/lib/python3.9/site-packages/lux/core/frame.py", line 436, in maintain_recs
#     custom_action_collection = custom_actions(rec_df)
# ...

# %%
dfeu = df[(df['provider'] == 'Europa') & (df['tariff_name'] == 'E-RL N10')]

# %%
for row, rdf in dfeu.groupby('dob'):
    print(row)
    print(rdf['price'])
# Out:
# 1966
# 53       158.74
# 2782     158.74
# 5142     113.11
# 7497     100.97
# 8673     113.11
# 10571     84.13
# 12885     84.13
# 15814    110.95
# 19376    158.74
# 20611    113.11
# 23129    113.11
# 25108    113.11
# 27768    100.97
# 29969    113.11
# 32636    100.97
# 35265    100.97
# 37522     77.13
# 39848     75.58
# 41709     68.91
# 43772    104.64
# 46292    113.11
# 48727    113.11
# 51040    113.11
# 53005     72.54
# 55827     72.54
# 57162    110.95
# 59148     69.44
# 60422     98.15
# 61173     69.44
# 63006     80.42
# 65472     75.58
# 70111     82.74
# Name: price, dtype: object
# 1967
# 151      145.15
# 2808     145.15
# 5223      99.52
# 7470      88.55
# 9337      99.52
# 11477     73.63
# 13511     73.63
# 15726     97.62
# 19521    145.15
# 20690     99.52
# 23099     99.52
# 25625     99.52
# 27269     88.55
# 30596     99.52
# 32142     88.55
# 35300     88.55
# 37827     67.47
# 39920     66.13
# 42071     60.36
# 44356     92.06
# 46317     99.52
# ...

# %%
x = x[x['smoker'] == 'yes']

# %%
x
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
x.intent = ["dob","price"]
x
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()
