# %%
import dataset

# %%
# db = dataset.connect("sqlite:///data.sqlite")
db = dataset.connect("postgresql://postgres:postgres@localhost:5432/postgres")
tab_res = db["results"]
tab_errors = db["errors"]

# %%
list(tab_res.all())[:10]
# Out:
# [OrderedDict([('id', 1),
#               ('url',
#                'https://vorsorge.check24.de/risikoleben/vergleichsergebnis/?c24api_rs_lang=&c24api_rs_session=&c24login_type=none&c24api_realestateproprietor=no&c24api_insurepersondiffers=no&c24api_children_discount=no&c24api_loannotolderthansixmonths=no&c24_controller=result&c24_calculate=x&c24api_currentinsurancetype=&c24api_smoker=no&c24api_nonsmokeryears=255&c24api_birthdate=1974-12-13&c24api_protectiontype=constant&c24api_protectiontarget=family&c24api_occupation_id=3&c24api_sum_course=decreasing_linearly&c24api_sortfield=price&c24api_sortorder=asc&has_filter_active=false&c24api_insure_sum=200.000&c24api_insure_period=20&c24api_paymentperiod=month&c24api_occupation_name=Abbrucharbeiter/in&c24api_insure_date=2022-04-01'),
#               ('tariff_id', '732'),
#               ('tariff_name', 'Alpha N10'),
#               ('tariff_variation', '34946-b-136316'),
#               ('tariff_grade', '1.2'),
#               ('promotion_position', 'first'),
#               ('provider', 'Aeguron'),
#               ('price', '32.9'),
#               ('created_at',
#                datetime.datetime(2022, 3, 24, 14, 17, 20, 915297)),
#               ('oc_id', '3'),
#               ('oc_name', 'Abbrucharbeiter/in'),
#               ('dob', '1974-12-13'),
#               ('smoker', 'no'),
#               ('rank', 0)]),
#  OrderedDict([('id', 2),
#               ('url',
#                'https://vorsorge.check24.de/risikoleben/vergleichsergebnis/?c24api_rs_lang=&c24api_rs_session=&c24login_type=none&c24api_realestateproprietor=no&c24api_insurepersondiffers=no&c24api_children_discount=no&c24api_loannotolderthansixmonths=no&c24_controller=result&c24_calculate=x&c24api_currentinsurancetype=&c24api_smoker=no&c24api_nonsmokeryears=255&c24api_birthdate=1974-12-13&c24api_protectiontype=constant&c24api_protectiontarget=family&c24api_occupation_id=3&c24api_sum_course=decreasing_linearly&c24api_sortfield=price&c24api_sortorder=asc&has_filter_active=false&c24api_insure_sum=200.000&c24api_insure_period=20&c24api_paymentperiod=month&c24api_occupation_name=Abbrucharbeiter/in&c24api_insure_date=2022-04-01'),
#               ('tariff_id', '756'),
#               ('tariff_name', 'Alpha N10 UZ'),
#               ('tariff_variation', '33842-b-132132'),
#               ('tariff_grade', '1.2'),
#               ('promotion_position', 'first'),
#               ('provider', 'Aeguron'),
#               ('price', '35.89'),
#               ('created_at',
#                datetime.datetime(2022, 3, 24, 14, 17, 20, 915297)),
#               ('oc_id', '3'),
#               ('oc_name', 'Abbrucharbeiter/in'),
#               ('dob', '1974-12-13'),
#               ('smoker', 'no'),
#               ('rank', 1)]),
#  OrderedDict([('id', 3),
#               ('url',
#                'https://vorsorge.check24.de/risikoleben/vergleichsergebnis/?c24api_rs_lang=&c24api_rs_session=&c24login_type=none&c24api_realestateproprietor=no&c24api_insurepersondiffers=no&c24api_children_discount=no&c24api_loannotolderthansixmonths=no&c24_controller=result&c24_calculate=x&c24api_currentinsurancetype=&c24api_smoker=no&c24api_nonsmokeryears=255&c24api_birthdate=1974-12-13&c24api_protectiontype=constant&c24api_protectiontarget=family&c24api_occupation_id=3&c24api_sum_course=decreasing_linearly&c24api_sortfield=price&c24api_sortorder=asc&has_filter_active=false&c24api_insure_sum=200.000&c24api_insure_period=20&c24api_paymentperiod=month&c24api_occupation_name=Abbrucharbeiter/in&c24api_insure_date=2022-04-01'),
#               ('tariff_id', '880'),
#               ('tariff_name', 'Klassik N10'),
#               ('tariff_variation', '33892-b-132332'),
#               ('tariff_grade', '1.3'),
#               ('promotion_position', 'none'),
#               ('provider', 'Verti'),
#               ('price', '37.22'),
#               ('created_at',
#                datetime.datetime(2022, 3, 24, 14, 17, 20, 915297)),
#               ('oc_id', '3'),
#               ('oc_name', 'Abbrucharbeiter/in'),
#               ('dob', '1974-12-13'),
#               ('smoker', 'no'),
#               ('rank', 2)]),
#  OrderedDict([('id', 4),
#               ('url',
#                'https://vorsorge.check24.de/risikoleben/vergleichsergebnis/?c24api_rs_lang=&c24api_rs_session=&c24login_type=none&c24api_realestateproprietor=no&c24api_insurepersondiffers=no&c24api_children_discount=no&c24api_loannotolderthansixmonths=no&c24_controller=result&c24_calculate=x&c24api_currentinsurancetype=&c24api_smoker=no&c24api_nonsmokeryears=255&c24api_birthdate=1974-12-13&c24api_protectiontype=constant&c24api_protectiontarget=family&c24api_occupation_id=3&c24api_sum_course=decreasing_linearly&c24api_sortfield=price&c24api_sortorder=asc&has_filter_active=false&c24api_insure_sum=200.000&c24api_insure_period=20&c24api_paymentperiod=month&c24api_occupation_name=Abbrucharbeiter/in&c24api_insure_date=2022-04-01'),
#               ('tariff_id', '480'),
#               ('tariff_name', 'Dela aktiv Leben K'),
#               ('tariff_variation', '34182-b-133164'),
#               ('tariff_grade', '1.5'),
#               ('promotion_position', 'first'),
#               ('provider', 'DELA'),
#               ('price', '38.22'),
#               ('created_at',
#                datetime.datetime(2022, 3, 24, 14, 17, 20, 915297)),
#               ('oc_id', '3'),
#               ('oc_name', 'Abbrucharbeiter/in'),
#               ('dob', '1974-12-13'),
#               ('smoker', 'no'),
#               ('rank', 3)]),
#  OrderedDict([('id', 5),
#               ('url',
#                'https://vorsorge.check24.de/risikoleben/vergleichsergebnis/?c24api_rs_lang=&c24api_rs_session=&c24login_type=none&c24api_realestateproprietor=no&c24api_insurepersondiffers=no&c24api_children_discount=no&c24api_loannotolderthansixmonths=no&c24_controller=result&c24_calculate=x&c24api_currentinsurancetype=&c24api_smoker=no&c24api_nonsmokeryears=255&c24api_birthdate=1974-12-13&c24api_protectiontype=constant&c24api_protectiontarget=family&c24api_occupation_id=3&c24api_sum_course=decreasing_linearly&c24api_sortfield=price&c24api_sortorder=asc&has_filter_active=false&c24api_insure_sum=200.000&c24api_insure_period=20&c24api_paymentperiod=month&c24api_occupation_name=Abbrucharbeiter/in&c24api_insure_date=2022-04-01'),
#               ('tariff_id', '892'),
#               ('tariff_name', 'Klassik N10 UZ'),
#               ('tariff_variation', '33878-b-132276'),
#               ('tariff_grade', '1.3'),
#               ('promotion_position', 'none'),
#               ('provider', 'Verti'),
#               ('price', '42.22'),
#               ('created_at',
#                datetime.datetime(2022, 3, 24, 14, 17, 20, 915297)),
#               ('oc_id', '3'),
#               ('oc_name', 'Abbrucharbeiter/in'),
#               ('dob', '1974-12-13'),
#               ('smoker', 'no'),
#               ('rank', 4)]),
#  OrderedDict([('id', 6),
#               ('url',
#                'https://vorsorge.check24.de/risikoleben/vergleichsergebnis/?c24api_rs_lang=&c24api_rs_session=&c24login_type=none&c24api_realestateproprietor=no&c24api_insurepersondiffers=no&c24api_children_discount=no&c24api_loannotolderthansixmonths=no&c24_controller=result&c24_calculate=x&c24api_currentinsurancetype=&c24api_smoker=no&c24api_nonsmokeryears=255&c24api_birthdate=1974-12-13&c24api_protectiontype=constant&c24api_protectiontarget=family&c24api_occupation_id=3&c24api_sum_course=decreasing_linearly&c24api_sortfield=price&c24api_sortorder=asc&has_filter_active=false&c24api_insure_sum=200.000&c24api_insure_period=20&c24api_paymentperiod=month&c24api_occupation_name=Abbrucharbeiter/in&c24api_insure_date=2022-04-01'),
#               ('tariff_id', '1100'),
#               ('tariff_name', 'RISK-vario® Basic (KV) N10'),
#               ('tariff_variation', '31904-b-124852'),
#               ('tariff_grade', '1.9'),
#               ('promotion_position', 'none'),
#               ('provider', 'Dialog'),
#               ('price', '43.44'),
#               ('created_at',
#                datetime.datetime(2022, 3, 24, 14, 17, 20, 915297)),
#               ('oc_id', '3'),
#               ('oc_name', 'Abbrucharbeiter/in'),
#               ('dob', '1974-12-13'),
#               ('smoker', 'no'),
#               ('rank', 5)]),
#  OrderedDict([('id', 7),
#               ('url',
#                'https://vorsorge.check24.de/risikoleben/vergleichsergebnis/?c24api_rs_lang=&c24api_rs_session=&c24login_type=none&c24api_realestateproprietor=no&c24api_insurepersondiffers=no&c24api_children_discount=no&c24api_loannotolderthansixmonths=no&c24_controller=result&c24_calculate=x&c24api_currentinsurancetype=&c24api_smoker=no&c24api_nonsmokeryears=255&c24api_birthdate=1974-12-13&c24api_protectiontype=constant&c24api_protectiontarget=family&c24api_occupation_id=3&c24api_sum_course=decreasing_linearly&c24api_sortfield=price&c24api_sortorder=asc&has_filter_active=false&c24api_insure_sum=200.000&c24api_insure_period=20&c24api_paymentperiod=month&c24api_occupation_name=Abbrucharbeiter/in&c24api_insure_date=2022-04-01'),
#               ('tariff_id', '318'),
#               ('tariff_name', 'T1 N10'),
#               ('tariff_variation', '34892-b-136100'),
#               ('tariff_grade', '1.1'),
#               ('promotion_position', 'all'),
#               ('provider', 'Hannoversche'),
#               ('price', '44.35'),
#               ('created_at',
#                datetime.datetime(2022, 3, 24, 14, 17, 20, 915297)),
#               ('oc_id', '3'),
#               ('oc_name', 'Abbrucharbeiter/in'),
#               ('dob', '1974-12-13'),
#               ('smoker', 'no'),
#               ('rank', 6)]),
#  OrderedDict([('id', 8),
#               ('url',
#                'https://vorsorge.check24.de/risikoleben/vergleichsergebnis/?c24api_rs_lang=&c24api_rs_session=&c24login_type=none&c24api_realestateproprietor=no&c24api_insurepersondiffers=no&c24api_children_discount=no&c24api_loannotolderthansixmonths=no&c24_controller=result&c24_calculate=x&c24api_currentinsurancetype=&c24api_smoker=no&c24api_nonsmokeryears=255&c24api_birthdate=1974-12-13&c24api_protectiontype=constant&c24api_protectiontarget=family&c24api_occupation_id=3&c24api_sum_course=decreasing_linearly&c24api_sortfield=price&c24api_sortorder=asc&has_filter_active=false&c24api_insure_sum=200.000&c24api_insure_period=20&c24api_paymentperiod=month&c24api_occupation_name=Abbrucharbeiter/in&c24api_insure_date=2022-04-01'),
#               ('tariff_id', '864'),
#               ('tariff_name', 'Basis (R1) 10'),
#               ('tariff_variation', '34986-b-136476'),
#               ('tariff_grade', '2'),
#               ('promotion_position', 'none'),
#               ('provider', 'WGV'),
#               ('price', '46.7'),
#               ('created_at',
#                datetime.datetime(2022, 3, 24, 14, 17, 20, 915297)),
#               ('oc_id', '3'),
#               ('oc_name', 'Abbrucharbeiter/in'),
#               ('dob', '1974-12-13'),
#               ('smoker', 'no'),
#               ('rank', 7)]),
#  OrderedDict([('id', 9),
#               ('url',
#                'https://vorsorge.check24.de/risikoleben/vergleichsergebnis/?c24api_rs_lang=&c24api_rs_session=&c24login_type=none&c24api_realestateproprietor=no&c24api_insurepersondiffers=no&c24api_children_discount=no&c24api_loannotolderthansixmonths=no&c24_controller=result&c24_calculate=x&c24api_currentinsurancetype=&c24api_smoker=no&c24api_nonsmokeryears=255&c24api_birthdate=1974-12-13&c24api_protectiontype=constant&c24api_protectiontarget=family&c24api_occupation_id=3&c24api_sum_course=decreasing_linearly&c24api_sortfield=price&c24api_sortorder=asc&has_filter_active=false&c24api_insure_sum=200.000&c24api_insure_period=20&c24api_paymentperiod=month&c24api_occupation_name=Abbrucharbeiter/in&c24api_insure_date=2022-04-01'),
#               ('tariff_id', '298'),
#               ('tariff_name', 'Kompakt SB 10'),
#               ('tariff_variation', '32532-b-127352'),
#               ('tariff_grade', '1.6'),
#               ('promotion_position', 'none'),
#               ('provider', 'Württembergische'),
#               ('price', '49.04'),
#               ('created_at',
#                datetime.datetime(2022, 3, 24, 14, 17, 20, 915297)),
#               ('oc_id', '3'),
#               ('oc_name', 'Abbrucharbeiter/in'),
#               ('dob', '1974-12-13'),
#               ('smoker', 'no'),
#               ('rank', 8)]),
#  OrderedDict([('id', 10),
#               ('url',
#                'https://vorsorge.check24.de/risikoleben/vergleichsergebnis/?c24api_rs_lang=&c24api_rs_session=&c24login_type=none&c24api_realestateproprietor=no&c24api_insurepersondiffers=no&c24api_children_discount=no&c24api_loannotolderthansixmonths=no&c24_controller=result&c24_calculate=x&c24api_currentinsurancetype=&c24api_smoker=no&c24api_nonsmokeryears=255&c24api_birthdate=1974-12-13&c24api_protectiontype=constant&c24api_protectiontarget=family&c24api_occupation_id=3&c24api_sum_course=decreasing_linearly&c24api_sortfield=price&c24api_sortorder=asc&has_filter_active=false&c24api_insure_sum=200.000&c24api_insure_period=20&c24api_paymentperiod=month&c24api_occupation_name=Abbrucharbeiter/in&c24api_insure_date=2022-04-01'),
#               ('tariff_id', '1018'),
#               ('tariff_name', 'Dela aktiv Leben Plus K'),
#               ('tariff_variation', '34172-b-133124'),
#               ('tariff_grade', '1.1'),
#               ('promotion_position', 'first'),
#               ('provider', 'DELA'),
#               ('price', '49.41'),
#               ('created_at',
#                datetime.datetime(2022, 3, 24, 14, 17, 20, 915297)),
#               ('oc_id', '3'),
#               ('oc_name', 'Abbrucharbeiter/in'),
#               ('dob', '1974-12-13'),
#               ('smoker', 'no'),
#               ('rank', 9)])]

# %%
list(tab_errors.all())[-10]
# Out:
# OrderedDict([('id', 1836),
#              ('created_at',
#               datetime.datetime(2022, 3, 24, 14, 48, 36, 254732)),
#              ('url',
#               'https://vorsorge.check24.de/risikoleben/vergleichsergebnis/?c24api_rs_lang=&c24api_rs_session=&c24login_type=none&c24api_realestateproprietor=no&c24api_insurepersondiffers=no&c24api_children_discount=no&c24api_loannotolderthansixmonths=no&c24_controller=result&c24_calculate=x&c24api_currentinsurancetype=&c24api_smoker=yes&c24api_nonsmokeryears=255&c24api_birthdate=1962-12-13&c24api_protectiontype=constant&c24api_protectiontarget=family&c24api_occupation_id=35&c24api_sum_course=decreasing_linearly&c24api_sortfield=price&c24api_sortorder=asc&has_filter_active=false&c24api_insure_sum=200.000&c24api_insure_period=20&c24api_paymentperiod=month&c24api_occupation_name=Agrarwirtschaftsassistent/in&c24api_insure_date=2022-04-01'),
#              ('oc_id', '35'),
#              ('oc_name', 'Agrarwirtschaftsassistent/in'),
#              ('dob', '1962-12-13'),
#              ('smoker', 'yes')])
